# %%
from pca import PCAPlotting

# %% [markdown]
# 1. import merged data
# 2. remove regions that contain >= 85% of data being NaN
# 3. fill all NaNs with 0s

# %%
from data import Data
data = Data()
data.filter_low_data_regions(threshold=0.15)
data.fill_na(0)
data.normalize_regions()
dat = data.d
# Out:
# /Users/admin/COMP551/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3417: DtypeWarning: Columns (15) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %% [markdown]
# Generate a PCA-reduced dataset and generate an elbow graph for the first 10
# dimensions demonstrating the percent of variance each dimension accounts for.

# %%
pca = PCAPlotting(dat)
pca.plot_optimal_pc(20)

# %% [markdown]
# Print percentage of variance covered for each dimension added

# %%
variance = 0
for i in range(len(pca.pca.explained_variance_ratio_)):
    variance += pca.pca.explained_variance_ratio_[i] * 100
    print(f"{i+1} Dimension(s) account for {variance}% of the dataset variance." )
# Out:
# 1 Dimension(s) account for 44.129978212766666% of the dataset variance.
# 2 Dimension(s) account for 59.74013451080108% of the dataset variance.
# 3 Dimension(s) account for 68.9395890479418% of the dataset variance.
# 4 Dimension(s) account for 74.74399663406926% of the dataset variance.
# 5 Dimension(s) account for 79.28390289306387% of the dataset variance.
# 6 Dimension(s) account for 81.79016563754038% of the dataset variance.
# 7 Dimension(s) account for 84.12157698330893% of the dataset variance.
# 8 Dimension(s) account for 85.88230190992871% of the dataset variance.
# 9 Dimension(s) account for 87.56130040292277% of the dataset variance.
# 10 Dimension(s) account for 88.68153441381727% of the dataset variance.
# 11 Dimension(s) account for 89.59488502007656% of the dataset variance.
# 12 Dimension(s) account for 90.31378972464277% of the dataset variance.
# 13 Dimension(s) account for 90.97120935641634% of the dataset variance.
# ...

# %% [markdown]
# For visibility, generate a two dimensional and third dimensional graph to
# display the PCA reduced data

# %%
pca.reduce_dimensionality(2)
pca.plot_data()
pca.reduce_dimensionality(3)
pca.plot_data()
